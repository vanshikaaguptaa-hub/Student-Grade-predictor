# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
students_df = pd.read_csv('student_grade_predictor.csv')
students_df.head(10)
# Out:
#   StudentID          Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0      S001  Aarav Sharma    Male              92                 18
# 1      S002   Priya Patel  Female              78                 10
# 2      S003   Rohan Mehta    Male              65                  6
# 3      S004  Ananya Singh  Female              95                 22
# 4      S005   Karan Gupta    Male              55                  4
# 5      S006   Sneha Reddy  Female              88                 16
# 6      S007   Vikram Nair    Male              72                  9
# 7      S008    Divya Iyer  Female              98                 25
# 8      S009   Arjun Verma    Male              60                  5
# 9      S010   Meera Joshi  Female              85                 14
#
#    PreviousGrade ExtracurricularActivities ParentalSupport  FinalGrade  \
# 0             85                       Yes            High          88
# 1             70                        No          Medium          72
# 2             58                        No             Low          55
# 3             91                       Yes            High          93
# 4             50                        No             Low          48
# 5             80                       Yes            High          84
# 6             65                        No          Medium          67
# 7             95                       Yes            High          96
# 8             55                        No             Low          52
# 9             78                       Yes          Medium          80
#
#    Study Hours  Attendance (%)  Online Classes Taken
# 0           18              92                     5
# 1           10              78                     2
# 2            6              65                     1
# 3           22              95                     7
# 4            4              55                     0
# 5           16              88                     6
# 6            9              72                     3
# 7           25              98                     8
# 8            5              60                     1
# 9           14              85                     4

# %%
students_df.shape # There are 1000 rows and 12 columns
# Out:
# (100, 12)

# %%
students_df.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'AttendanceRate', 'StudyHoursPerWeek',
#        'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport',
#        'FinalGrade', 'Study Hours', 'Attendance (%)', 'Online Classes Taken'],
#       dtype='object')

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  100 non-null    object
#  1   Name                       100 non-null    object
#  2   Gender                     100 non-null    object
#  3   AttendanceRate             100 non-null    int64
#  4   StudyHoursPerWeek          100 non-null    int64
#  5   PreviousGrade              100 non-null    int64
#  6   ExtracurricularActivities  100 non-null    object
#  7   ParentalSupport            100 non-null    object
#  8   FinalGrade                 100 non-null    int64
#  9   Study Hours                100 non-null    int64
#  10  Attendance (%)             100 non-null    int64
#  11  Online Classes Taken       100 non-null    int64
# dtypes: int64(7), object(5)
# memory usage: 9.5+ KB

# %%
students_df.describe()
# Out:
#        AttendanceRate  StudyHoursPerWeek  PreviousGrade  FinalGrade  \
# count      100.000000         100.000000     100.000000  100.000000
# mean        75.690000          11.960000      69.610000   69.970000
# std         15.366036           6.672603      15.889705   18.013718
# min         46.000000           3.000000      40.000000   37.000000
# 25%         63.000000           6.000000      57.000000   54.000000
# 50%         78.000000          11.000000      70.500000   72.500000
# 75%         89.000000          17.000000      83.000000   86.000000
# max         98.000000          25.000000      95.000000   96.000000
#
#        Study Hours  Attendance (%)  Online Classes Taken
# count   100.000000      100.000000            100.000000
# mean     11.960000       75.690000              3.220000
# std       6.672603       15.366036              2.576428
# min       3.000000       46.000000              0.000000
# 25%       6.000000       63.000000              1.000000
# 50%      11.000000       78.000000              3.000000
# 75%      17.000000       89.000000              5.000000
# max      25.000000       98.000000              9.000000

# %%
num_cols = [
    'AttendanceRate',
    'StudyHoursPerWeek',
    'PreviousGrade',
    'FinalGrade',
    'Study Hours',
    'Attendance (%)'
]

# %%
sns.heatmap(students_df[num_cols].corr(),
            annot=True,
            cmap = "coolwarm",
            fmt=".2f",
            linewidths="0.5")
plt.title("Correlation Heatmap of Sutdents Performance");
